# %% [markdown]
# <a href="https://colab.research.google.com/github/Thilak-K21/ML-LAB/blob/main/LAB01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("housing.csv")
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.groupby('ocean_proximity')['ocean_proximity'].count()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# ISLAND           5
# NEAR BAY      2290
# NEAR OCEAN    2658
# Name: ocean_proximity, dtype: int64

# %%
missing= df.isnull().sum()
missing[missing > 0]
# Out:
# total_bedrooms    207
# dtype: int64

# %% [markdown]
# # **LAB 2 Preprocessing**

# %%
import pandas as pd
df=pd.read_csv("diabetes.csv")
df.isnull().sum()
df.describe()
df[["BMI", "Urea", "Cr", "HbA1c", "Chol", "TG", "HDL", "LDL", "VLDL"]].min()
# Out:
# BMI      19.0
# Urea      0.5
# Cr        6.0
# HbA1c     0.9
# Chol      0.0
# TG        0.3
# HDL       0.2
# LDL       0.3
# VLDL      0.1
# dtype: float64

# %%
import numpy as np

df["Chol"] = df["Chol"].replace(0, np.nan)

# %%
df.isnull().sum()
# Out:
# ID           0
# No_Pation    0
# Gender       0
# AGE          0
# Urea         0
# Cr           0
# HbA1c        0
# Chol         1
# TG           0
# HDL          0
# LDL          0
# VLDL         0
# BMI          0
# CLASS        0
# dtype: int64

# %%
df["Gender"].value_counts()
# Out:
# Gender
# M    565
# F    434
# f      1
# Name: count, dtype: int64

# %%
df["Gender"] = df["Gender"].replace('f', 'F')

# %%
df["Gender"].value_counts()
# Out:
# Gender
# M    565
# F    435
# Name: count, dtype: int64

# %%
df["Gender"] = df["Gender"].map({"M": 1, "F": 0})

# %%
df.head()
# Out:
#     ID  No_Pation  Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0  502      17975       0   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1  735      34221       1   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2  420      47975       0   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3  680      87656       0   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4  504      34223       1   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
#
#     BMI CLASS
# 0  24.0     N
# 1  23.0     N
# 2  24.0     N
# 3  24.0     N
# 4  21.0     N

# %%
#Handling class
df["CLASS"].value_counts()
# Out:
# CLASS
# Y     840
# N     102
# P      53
# Y       4
# N       1
# Name: count, dtype: int64

# %%
df["CLASS"] = df["CLASS"].astype(str).str.strip().str.upper()

# %%
df["CLASS"].value_counts()
# Out:
# CLASS
# Y    844
# N    103
# P     53
# Name: count, dtype: int64

# %%
df["CLASS"] = df["CLASS"].map({
    "N": 0,
    "P": 1,
    "Y": 2
})

# %%
df["CLASS"].value_counts()
# Out:
# CLASS
# 2    844
# 0    103
# 1     53
# Name: count, dtype: int64

# %%
numeric_cols = df.select_dtypes(include="number").columns
numeric_cols
# Out:
# Index(['ID', 'No_Pation', 'Gender', 'AGE', 'Urea', 'Cr', 'HbA1c', 'Chol', 'TG',
#        'HDL', 'LDL', 'VLDL', 'BMI', 'CLASS'],
#       dtype='object')

# %%
features = ['AGE', 'Urea', 'Cr', 'HbA1c', 'Chol', 'TG', 'HDL', 'LDL', 'VLDL', 'BMI', 'Gender']
numeric_df = df[features]
numeric_df.describe()
# Out:
#                AGE         Urea           Cr        HbA1c        Chol  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  999.000000
# mean     53.528000     5.124743    68.943000     8.281160    4.867688
# std       8.799241     2.935165    59.984747     2.534003    1.293252
# min      20.000000     0.500000     6.000000     0.900000    0.500000
# 25%      51.000000     3.700000    48.000000     6.500000    4.000000
# 50%      55.000000     4.600000    60.000000     8.000000    4.800000
# 75%      59.000000     5.700000    73.000000    10.200000    5.600000
# max      79.000000    38.900000   800.000000    16.000000   10.300000
#
#                 TG          HDL          LDL         VLDL          BMI  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      2.349610     1.204750     2.609790     1.854700    29.578020
# std       1.401176     0.660414     1.115102     3.663599     4.962388
# ...

# %%
Q1 = numeric_df.quantile(0.25)
Q3 = numeric_df.quantile(0.75)
IQR = Q3 - Q1

outliers = ((numeric_df < (Q1 - 1.5 * IQR)) | (numeric_df > (Q3 + 1.5 * IQR)))
outliers.sum()
# Out:
# AGE       98
# Urea      65
# Cr        52
# HbA1c      6
# Chol      26
# TG        55
# HDL       50
# LDL       11
# VLDL      74
# BMI        3
# Gender     0
# dtype: int64

# %%
for col in features:
    lower = Q1[col] - 1.5 * IQR[col]
    upper = Q3[col] + 1.5 * IQR[col]
    df.loc[:, col] = df[col].clip(lower, upper)
# Out:
# /tmp/ipython-input-2641973318.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 46.   62.   46.   46.   46.   24.   50.   47.   67.   28.   55.   53.
#   42.   54.   39.   74.   53.   42.   28.   55.  110.5  73.   62.   28.
#   55.   45.   80.   99.   54.   49.   82.   55.   70.   73.   67.   67.
#   20.   54.   74.   48.   31.   39.   54.   44.   47.   74.   67.   60.
#   39.   48.   49.   57.   40.   53.   69.   52.   52.   32.   38.   42.
#   55.   45.   85.   64.   38.   63.   50.   45.   38.   10.5  40.   48.
#   39.   54.   56.   58.   44.   88.   61.   61.   97.   88.   61.  106.
#   70.   61.   35.  110.5  79.   97.   79.  110.5  70.  106.  110.5 110.5
#  106.   70.   70.  106.   58.   97.   83.   81.   81.   81.   55.   55.
#   55.   53.   87.   59.   74.   53.   59.   44.   74.   44.   53.   59.
#   44.   38.   59.   46.   75.   38.   74.   64.   62.   53.   47.   53.
# ...

# %%
df[features].describe()
# Out:
#                AGE         Urea           Cr        HbA1c        Chol  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  999.000000
# mean     53.986000     4.826843    62.345000     8.280960    4.846667
# std       7.363968     1.714231    20.297906     2.532224    1.206270
# min      39.000000     0.700000    10.500000     0.950000    1.600000
# 25%      51.000000     3.700000    48.000000     6.500000    4.000000
# 50%      55.000000     4.600000    60.000000     8.000000    4.800000
# 75%      59.000000     5.700000    73.000000    10.200000    5.600000
# max      71.000000     8.700000   110.500000    15.750000    8.000000
#
#                 TG          HDL          LDL        VLDL          BMI  \
# count  1000.000000  1000.000000  1000.000000  1000.00000  1000.000000
# mean      2.280610     1.142250     2.591640     1.14040    29.566770
# std       1.150887     0.348675     1.039511     0.62744     4.926358
# ...

# %%
df[features] = numeric_df

# %%
df
# Out:
#       ID  No_Pation  Gender  AGE  Urea    Cr  HbA1c  Chol   TG  HDL  LDL  \
# 0    502      17975       0   50   4.7  46.0    4.9   4.2  0.9  1.9  1.4
# 1    735      34221       1   39   4.5  62.0    4.9   3.7  1.4  1.1  2.1
# 2    420      47975       0   50   4.7  46.0    4.9   4.2  0.9  1.9  1.4
# 3    680      87656       0   50   4.7  46.0    4.9   4.2  0.9  1.9  1.4
# 4    504      34223       1   39   7.1  46.0    4.9   4.9  1.0  0.8  2.0
# ..   ...        ...     ...  ...   ...   ...    ...   ...  ...  ...  ...
# 995  200     454317       1   71   8.7  97.0    7.0   7.5  1.7  1.2  1.8
# 996  671     876534       1   39   3.0  60.0   12.3   4.1  2.2  0.7  2.4
# 997  669      87654       1   39   7.1  81.0    6.7   4.1  1.1  1.2  2.4
# 998   99      24004       1   39   5.8  59.0    6.7   5.3  2.0  1.6  2.9
# 999  248      24054       1   54   5.0  67.0    6.9   3.8  1.7  1.1  3.0
#
#      VLDL   BMI  CLASS
# 0     0.5  24.0      0
# 1     0.6  23.0      0
# ...
